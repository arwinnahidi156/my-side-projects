# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  
import sklearn

# %%
df=pd.read_csv('Advertising.csv')
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df['total_spend']=df['TV']+df['radio']+df['newspaper']

# %%
sns.regplot(data=df,x='total_spend',y='sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
# X=df['total_spend']
y=df['sales']
beta=np.polyfit(X,y,deg=1)
potential_spend=np.linspace(0,500,100)
predicted_sales=beta[0]*potential_spend + beta[1]
sns.scatterplot(data=df,x='total_spend',y='sales')
plt.plot(potential_spend,predicted_sales,'r')

# %%
spend=200
predicted_sales=beta[0]*spend + beta[1]
predicted_sales
# Out:
# 13.98060407984596

# %%
beta=np.polyfit(X,y,deg=3)
potential_spend=np.linspace(0,500,100)
predicted_sales=beta[0]*potential_spend**3 +beta[1]*potential_spend**2 +beta[2]*potential_spend**1
+beta[3]*potential_spend 
sns.scatterplot(data=df,x='total_spend',y='sales')
plt.plot(potential_spend,predicted_sales,'r')

# %%
X=df['TV']+df['radio']+df['newspaper']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
X_train
# Out:
# 57     172.0
# 174    238.9
# 171    232.8
# 163    207.7
# 115    162.8
#        ...
# 5      132.6
# 135    103.8
# 48     292.9
# 167    231.4
# 125    124.9
# Length: 150, dtype: float64
