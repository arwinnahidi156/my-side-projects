# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %%
fx=sym.Piecewise(
    (x/2, x<0),
    (x**2 + 1 , (0<=x)& (x<3)) ,
    (-sym.ln(x), x>=3),
)
sym.plot(fx)

# %%
fx1=sym.lambdify(fx,x)
xx=np.linspace(-3,5,1001)
plt.plot(xx,fx1(xx))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1192/1556795183.py in <module>
#       1 fx1=sym.lambdify(fx,x)
#       2 xx=np.linspace(-3,5,1001)
# ----> 3 plt.plot(xx,fx1(xx))
#
# /opt/anaconda/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/anaconda/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
