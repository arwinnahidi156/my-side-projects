# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../jupyter/environment/CIA_Country_Facts.csv')

# %%
df[df.Country=='Iran']
# Out:
#    Country                         Region  Population  Area (sq. mi.)  \
# 96    Iran  ASIA (EX. NEAR EAST)             68688433         1648000
#
#     Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 96                        41.7                          0.15          -0.84
#
#     Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 96                               41.58              7000.0          79.4
#
#     Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 96              276.4        8.72       1.39      89.89      1.0       17.0
#
#     Deathrate  Agriculture  Industry  Service
# 96       5.55        0.116     0.424     0.46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
pip install plotly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 944.5 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  2.270000e+02    2.270000e+02                  227.000000
# mean   2.874028e+07    5.982270e+05                  379.047137
# std    1.178913e+08    1.790282e+06                 1660.185825
# min    7.026000e+03    2.000000e+00                    0.000000
# 25%    4.376240e+05    4.647500e+03                   29.150000
# 50%    4.786994e+06    8.660000e+04                   78.800000
# 75%    1.749777e+07    4.418110e+05                  190.150000
# max    1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    227.000000     224.000000
# mean                      21.165330       0.038125
# std                       72.286863       4.889269
# min                        0.000000     -20.990000
# 25%                        0.100000      -0.927500
# 50%                        0.730000       0.000000
# ...

# %%
sns.histplot(data=df[df.Population<500000000],x='Population')
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.barplot(data=df,y='GDP ($ per capita)',x='Region')
plt.xticks(rotation=90);

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8),dpi=400)
sns.scatterplot(data=df,x='Phones (per 1000)', y='GDP ($ per capita)' ,hue='Region')
# plt.legend(loc=(1.05,0.5))
# Out:
# <Axes: xlabel='Phones (per 1000)', ylabel='GDP ($ per capita)'>

# %%
df[df['Phones (per 1000)']>900]
# Out:
#     Country                               Region  Population  Area (sq. mi.)  \
# 138  Monaco  WESTERN EUROPE                            32543               2
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 138                     16271.5                         205.0           7.75
#
#      Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 138                                5.43             27000.0          99.0
#
#      Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 138             1035.6         0.0        0.0      100.0      NaN       9.19
#
#      Deathrate  Agriculture  Industry  Service
# 138      12.91         0.17       NaN      NaN

# %%
df[df['GDP ($ per capita)']>50000]
# Out:
#         Country                               Region  Population  \
# 121  Luxembourg  WESTERN EUROPE                           474413
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 121            2586                       183.5                           0.0
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 121           8.97                                4.81             55100.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 121         100.0              515.4       23.28        0.4      76.32
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 121      NaN      11.94       8.41         0.01      0.13     0.86

# %%
plt.figure(figsize=(10,8),dpi=400)
sns.scatterplot(data=df,x= 'Literacy (%)', y='GDP ($ per capita)' ,hue='Region')
# plt.legend(loc=(1.05,0.5))
# Out:
# <Axes: xlabel='Literacy (%)', ylabel='GDP ($ per capita)'>

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.clustermap(df.corr(numeric_only=True))

# %%
df.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         1
# Infant mortality (per 1000 births)    1
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     2
# Arable (%)                            1
# Crops (%)                             1
# Other (%)                             1
# Climate                               0
# Birthrate                             1
# Deathrate                             2
# Agriculture                           0
# Industry                              1
# Service                               1
# dtype: int64

# %%
df[df.Agriculture.isnull()]=df[df.Agriculture.isnull()].fillna(0)

# %%
df.Climate.fillna(df.groupby('Region')['Climate'].transform('mean'),inplace=True)

# %%
df.groupby('Region')['Climate'].transform('mean')
# Out:
# 0      1.962963
# 1      3.111111
# 2      1.500000
# 3      2.000000
# 4      2.826087
#          ...
# 222    1.666667
# 223    1.500000
# 224    1.666667
# 225    1.846939
# 226    1.846939
# Name: Climate, Length: 227, dtype: float64

# %%
df['Literacy (%)'].fillna(df.groupby('Region')['Literacy (%)'].transform('mean'),inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
X=df.drop('Country',axis=1)

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
X
# Out:
#      Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0      31056997          647500                        48.0
# 1       3581655           28748                       124.6
# 2      32930091         2381740                        13.8
# 3         57794             199                       290.4
# 4         71201             468                       152.1
# ..          ...             ...                         ...
# 222     2460492            5860                       419.9
# 223      273008          266000                         1.0
# 224    21456188          527970                        40.6
# 225    11502010          752614                        15.3
# 226    12236805          390580                        31.3
#
#      Coastline (coast/area ratio)  Net migration  \
# 0                            0.00          23.06
# 1                            1.26          -4.93
# 2                            0.04          -0.39
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaled_X=scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

# %%
ssd=[]
for k in range(2,30):
    model=KMeans(n_clusters=k)
    model.fit_predict(scaled_X)
    ssd.append(model.inertia_)
# Out:
# /home/arwin/jupyter/environment/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/arwin/jupyter/environment/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/arwin/jupyter/environment/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(2,30),ssd,'o--')

# %%
model=KMeans(n_clusters=12)
labels=model.fit_predict(scaled_X)
# Out:
# /home/arwin/jupyter/environment/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df['label']=labels

# %%
df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
pd.Series(ssd).diff().plot(kind='bar')
# Out:
# <Axes: >

# %%
model=KMeans(n_clusters=5)
label=model.fit_predict(scaled_X)
# Out:
# /home/arwin/jupyter/environment/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df['k=5']=label

# %%
df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
X['k=3']=label

# %%
X.corr()['k=3'].sort_values()[:-1].plot(kind='bar')
# Out:
# <Axes: >

# %%
iso_codes=pd.read_csv('../jupyter/environment/country_iso_codes.csv')

# %%
iso_codes
# Out:
#                                              Country  \
# 0                                        Afghanistan
# 1    Akrotiri and Dhekelia – See United Kingdom, The
# 2                                      Åland Islands
# 3                                            Albania
# 4                                            Algeria
# ..                                               ...
# 296                                 Congo, Dem. Rep.
# 297                             Congo, Repub. of the
# 298                                         Tanzania
# 299                             Central African Rep.
# 300                                    Cote d'Ivoire
#
#                                             ISO Code
# 0                                                AFG
# 1    Akrotiri and Dhekelia – See United Kingdom, The
# 2                                                ALA
# 3                                                ALB
# 4                                                DZA
# ...

# %%
iso_map=iso_codes.set_index('Country')['ISO Code'].to_dict()

# %%
df['ISO Code']=df.Country.map(iso_map)

# %%
df
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
import plotly.express as px

fig = px.choropleth(df, locations="ISO Code",
                    color="k=5", # lifeExp is a column of gapminder
                    hover_name="Country", # column to add to hover information
#                     color_continuous_scale='Turbo'
                    )
fig.show()
# Out:
# <div>                            <div id="1db26d65-f646-45d8-aae1-e24323b34757" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1db26d65-f646-45d8-aae1-e24323b34757")) {                    Plotly.newPlot(                        "1db26d65-f646-45d8-aae1-e24323b34757",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eISO Code=%{location}\u003cbr\u003ek=5=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Albania","Algeria","American Samoa","Andorra","Angola","Anguilla","Antigua & Barbuda","Argentina","Armenia","Aruba","Australia","Austria","Azerbaijan","Bahamas, The","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize",
# ...
